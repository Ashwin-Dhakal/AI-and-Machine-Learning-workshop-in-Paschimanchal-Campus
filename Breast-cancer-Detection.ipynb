# %% [markdown]
# # Breast cancer data from University of california, Irvine

# %%
import numpy as np
from sklearn import model_selection, neighbors, preprocessing
import pandas as pd

# %% [markdown]
# ![title](cul.png)

# %%
df = pd.read_csv('breast-cancer-wisconsin.data.txt')

# %%
df.head()
# Out:
#         id  clump_thickness  uniformity_size  uniformity_shape  marginal_adh  \
# 0  1000025                5                1                 1             1
# 1  1002945                5                4                 4             5
# 2  1015425                3                1                 1             1
# 3  1016277                6                8                 8             1
# 4  1017023                4                1                 1             3
#
#    epithelial_size nuclei  chromatin  nucleoli  mitosis  class
# 0                2      1          3         1        1      2
# 1                7     10          3         2        1      2
# 2                2      2          3         1        1      2
# 3                3      4          3         7        1      2
# 4                2      1          3         1        1      2

# %% [markdown]
# # Data cleansing from the dataset provided

# %%
df
# Out:
#           id  clump_thickness  uniformity_size  uniformity_shape  \
# 0    1000025                5                1                 1
# 1    1002945                5                4                 4
# 2    1015425                3                1                 1
# 3    1016277                6                8                 8
# 4    1017023                4                1                 1
# 5    1017122                8               10                10
# 6    1018099                1                1                 1
# 7    1018561                2                1                 2
# 8    1033078                2                1                 1
# 9    1033078                4                2                 1
# 10   1035283                1                1                 1
# 11   1036172                2                1                 1
# 12   1041801                5                3                 3
# 13   1043999                1                1                 1
# 14   1044572                8                7                 5
# 15   1047630                7                4                 6
# 16   1048672                4                1                 1
# 17   1049815                4                1                 1
# 18   1050670               10                7                 7
# 19   1050718                6                1                 1
# 20   1054590                7                3                 2
# 21   1054593               10                5                 5
# 22   1056784                3                1                 1
# 23   1057013                8                4                 5
# 24   1059552                1                1                 1
# 25   1065726                5                2                 3
# 26   1066373                3                2                 1
# 27   1066979                5                1                 1
# 28   1067444                2                1                 1
# 29   1070935                1                1                 3
# ..       ...              ...              ...               ...
# 669  1350423                5               10                10
# 670  1352848                3               10                 7
# 671  1353092                3                2                 1
# 672  1354840                2                1                 1
# 673  1354840                5                3                 2
# 674  1355260                1                1                 1
# 675  1365075                4                1                 4
# 676  1365328                1                1                 2
# 677  1368267                5                1                 1
# 678  1368273                1                1                 1
# 679  1368882                2                1                 1
# 680  1369821               10               10                10
# 681  1371026                5               10                10
# 682  1371920                5                1                 1
# 683   466906                1                1                 1
# 684   466906                1                1                 1
# 685   534555                1                1                 1
# 686   536708                1                1                 1
# 687   566346                3                1                 1
# 688   603148                4                1                 1
# 689   654546                1                1                 1
# 690   654546                1                1                 1
# 691   695091                5               10                10
# 692   714039                3                1                 1
# 693   763235                3                1                 1
# 694   776715                3                1                 1
# 695   841769                2                1                 1
# 696   888820                5               10                10
# 697   897471                4                8                 6
# 698   897471                4                8                 8
#
#      marginal_adh  epithelial_size nuclei  chromatin  nucleoli  mitosis  class
# 0               1                2      1          3         1        1      2
# 1               5                7     10          3         2        1      2
# 2               1                2      2          3         1        1      2
# 3               1                3      4          3         7        1      2
# 4               3                2      1          3         1        1      2
# 5               8                7     10          9         7        1      4
# 6               1                2     10          3         1        1      2
# 7               1                2      1          3         1        1      2
# 8               1                2      1          1         1        5      2
# 9               1                2      1          2         1        1      2
# 10              1                1      1          3         1        1      2
# 11              1                2      1          2         1        1      2
# 12              3                2      3          4         4        1      4
# 13              1                2      3          3         1        1      2
# 14             10                7      9          5         5        4      4
# 15              4                6      1          4         3        1      4
# 16              1                2      1          2         1        1      2
# 17              1                2      1          3         1        1      2
# 18              6                4     10          4         1        2      4
# 19              1                2      1          3         1        1      2
# 20             10                5     10          5         4        4      4
# 21              3                6      7          7        10        1      4
# 22              1                2      1          2         1        1      2
# 23              1                2      ?          7         3        1      4
# 24              1                2      1          3         1        1      2
# 25              4                2      7          3         6        1      4
# 26              1                1      1          2         1        1      2
# 27              1                2      1          2         1        1      2
# 28              1                2      1          2         1        1      2
# 29              1                2      1          1         1        1      2
# ..            ...              ...    ...        ...       ...      ...    ...
# 669             8                5      5          7        10        1      4
# 670             8                5      8          7         4        1      4
# 671             2                2      1          3         1        1      2
# 672             1                2      1          3         1        1      2
# 673             1                3      1          1         1        1      2
# 674             1                2      1          2         1        1      2
# 675             1                2      1          1         1        1      2
# 676             1                2      1          2         1        1      2
# 677             1                2      1          1         1        1      2
# 678             1                2      1          1         1        1      2
# 679             1                2      1          1         1        1      2
# 680            10                5     10         10        10        7      4
# 681            10                4     10          5         6        3      4
# 682             1                2      1          3         2        1      2
# 683             1                2      1          1         1        1      2
# 684             1                2      1          1         1        1      2
# 685             1                2      1          1         1        1      2
# 686             1                2      1          1         1        1      2
# 687             1                2      1          2         3        1      2
# 688             1                2      1          1         1        1      2
# 689             1                2      1          1         1        8      2
# 690             3                2      1          1         1        1      2
# 691             5                4      5          4         4        1      4
# 692             1                2      1          1         1        1      2
# 693             1                2      1          2         1        2      2
# 694             1                3      2          1         1        1      2
# 695             1                2      1          1         1        1      2
# 696             3                7      3          8        10        2      4
# 697             4                3      4         10         6        1      4
# 698             5                4      5         10         4        1      4
#
# [699 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# id                  699 non-null int64
# clump_thickness     699 non-null int64
# uniformity_size     699 non-null int64
# uniformity_shape    699 non-null int64
# marginal_adh        699 non-null int64
# epithelial_size     699 non-null int64
# nuclei              699 non-null object
# chromatin           699 non-null int64
# nucleoli            699 non-null int64
# mitosis             699 non-null int64
# class               699 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 60.1+ KB

# %%
df.replace('?', -9999, inplace=True)

# %%
df.drop(['id'], 1, inplace=True)

# %%
df.head()
# Out:
#    clump_thickness  uniformity_size  uniformity_shape  marginal_adh  \
# 0                5                1                 1             1
# 1                5                4                 4             5
# 2                3                1                 1             1
# 3                6                8                 8             1
# 4                4                1                 1             3
#
#    epithelial_size nuclei  chromatin  nucleoli  mitosis  class
# 0                2      1          3         1        1      2
# 1                7     10          3         2        1      2
# 2                2      2          3         1        1      2
# 3                3      4          3         7        1      2
# 4                2      1          3         1        1      2

# %% [markdown]
# To get one value defined on the supervised learning algorithm

# %%
x = np.array(df.drop(['class'], 1))
y = np.array(df['class'])

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # We make use of KNN Algorithm

# %% [markdown]
# ![title](knn.png)

# %%
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
accuracy = clf.score(x_test, y_test)

# %%
print(accuracy)
# Out:
# 1.0

# %% [markdown]
# # Now we are testing our own example which is not is the dataset

# %%
testing_example = np.array([10,7,7,6,4,10,4,1,2])

# %%
testing_example = testing_example.reshape(1,-1)

# %%
prediction = clf.predict(testing_example)
print(prediction)
# Out:
# [4]

# %% [markdown]
# lets check one from the dataset itself

# %%
test_2 = np.array([8,10,10,8,7,10,9,7,1])
test_2 = test_2.reshape(1,-1)

# %%
prediction = clf.predict(test_2)
print(prediction)
# Out:
# [4]

# %% [markdown]
# Yeah Its correct !!! The actual dataset was: [8,10,10,8,7,10,9,7,1,4]
